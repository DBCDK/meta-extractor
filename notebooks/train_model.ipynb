# %% [markdown]
# # Quickstart for meta-extractor
# This notebook demonstrates how to install and use the `meta-extractor` package.
# It also contains examples of how to train a gemma3 model using your own data.
# This notebook uses the provided example data located in the `example_data/` folder.
#
# We suggest you find you own data to try out the training process, but the example data is provided for convenience.
# For more information see the README.md file.

# %% [markdown]
# ## 1. Install the package (editable mode for development)

# %%
# !pip install -e ../.
# Out:
# Looking in indexes: https://devpi.dbccloud.dk/dbc/packages
# Obtaining file:///home/kwc/github/meta-extractor
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: requests[socks] in /home/kwc/miniconda/lib/python3.12/site-packages (from meta-extractor==1.0) (2.32.3)
# Requirement already satisfied: pre-commit in /home/kwc/miniconda/lib/python3.12/site-packages (from meta-extractor==1.0) (4.2.0)
# Requirement already satisfied: pymupdf in /home/kwc/miniconda/lib/python3.12/site-packages (from meta-extractor==1.0) (1.26.4)
# Requirement already satisfied: tornado in /home/kwc/miniconda/lib/python3.12/site-packages (from meta-extractor==1.0) (6.4.1)
# Requirement already satisfied: transformers in /home/kwc/miniconda/lib/python3.12/site-packages (from meta-extractor==1.0) (4.57.0)
# Requirement already satisfied: cfgv>=2.0.0 in /home/kwc/miniconda/lib/python3.12/site-packages (from pre-commit->meta-extractor==1.0) (3.4.0)
# Requirement already satisfied: identify>=1.0.0 in /home/kwc/miniconda/lib/python3.12/site-packages (from pre-commit->meta-extractor==1.0) (2.6.10)
# Requirement already satisfied: nodeenv>=0.11.1 in /home/kwc/miniconda/lib/python3.12/site-packages (from pre-commit->meta-extractor==1.0) (1.9.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/kwc/miniconda/lib/python3.12/site-packages (from pre-commit->meta-extractor==1.0) (6.0.2)
# Requirement already satisfied: virtualenv>=20.10.0 in /home/kwc/miniconda/lib/python3.12/site-packages (from pre-commit->meta-extractor==1.0) (20.31.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/kwc/miniconda/lib/python3.12/site-packages (from requests[socks]->meta-extractor==1.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/kwc/miniconda/lib/python3.12/site-packages (from requests[socks]->meta-extractor==1.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/kwc/miniconda/lib/python3.12/site-packages (from requests[socks]->meta-extractor==1.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kwc/miniconda/lib/python3.12/site-packages (from requests[socks]->meta-extractor==1.0) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/kwc/miniconda/lib/python3.12/site-packages (from requests[socks]->meta-extractor==1.0) (1.7.1)
# Requirement already satisfied: filelock in /home/kwc/miniconda/lib/python3.12/site-packages (from transformers->meta-extractor==1.0) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /home/kwc/miniconda/lib/python3.12/site-packages (from transformers->meta-extractor==1.0) (0.35.3)
# Requirement already satisfied: numpy>=1.17 in /home/kwc/miniconda/lib/python3.12/site-packages (from transformers->meta-extractor==1.0) (2.2.5)
# Requirement already satisfied: packaging>=20.0 in /home/kwc/miniconda/lib/python3.12/site-packages (from transformers->meta-extractor==1.0) (24.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/kwc/miniconda/lib/python3.12/site-packages (from transformers->meta-extractor==1.0) (2025.7.34)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/kwc/miniconda/lib/python3.12/site-packages (from transformers->meta-extractor==1.0) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /home/kwc/miniconda/lib/python3.12/site-packages (from transformers->meta-extractor==1.0) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /home/kwc/miniconda/lib/python3.12/site-packages (from transformers->meta-extractor==1.0) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/kwc/miniconda/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers->meta-extractor==1.0) (2025.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/kwc/miniconda/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers->meta-extractor==1.0) (4.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/kwc/miniconda/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers->meta-extractor==1.0) (1.1.10)
# Requirement already satisfied: distlib<1,>=0.3.7 in /home/kwc/miniconda/lib/python3.12/site-packages (from virtualenv>=20.10.0->pre-commit->meta-extractor==1.0) (0.3.9)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /home/kwc/miniconda/lib/python3.12/site-packages (from virtualenv>=20.10.0->pre-commit->meta-extractor==1.0) (3.10.0)
# Building wheels for collected packages: meta-extractor
#   Building editable for meta-extractor (pyproject.toml) ... done
#   Created wheel for meta-extractor: filename=meta_extractor-1.0-0.editable-py3-none-any.whl size=15083 sha256=5759e9240d81810eb1c85b7e904048cd94327feeef842dc2a152ccee30540169
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gg6xbbo1/wheels/ef/6d/e4/cd89217db362638842078720f675d5d51fc9ac5e80fcbb4e84
# Successfully built meta-extractor
# Installing collected packages: meta-extractor
#   Attempting uninstall: meta-extractor
#     Found existing installation: meta-extractor 1.0
#     Uninstalling meta-extractor-1.0:
#       Successfully uninstalled meta-extractor-1.0
# Successfully installed meta-extractor-1.0

# %% [markdown]
# ## 2. Check the CLI entry point works

# %%
# !pdf2text --help
# Out:
# usage: pdf2text [-h] -i INPUT_DIRECTORY -o OUTPUT_DIRECTORY [-s]
#
# options:
#   -h, --help            show this help message and exit
#   -i INPUT_DIRECTORY, --input-directory INPUT_DIRECTORY
#                         path to directory where pdfs are stored.
#   -o OUTPUT_DIRECTORY, --output-directory OUTPUT_DIRECTORY
#                         path to directory where output text files will be
#                         stored.
#   -s, --short           only look at the first 3 pages instead of the first 13
#                         pages of the pdf

# %% [markdown]
# ## 3. Extract text from example PDF
# If you have your own PDFs, you can use the `pdf2text` command to extract text from them.
# Here we use the example PDFs provided in the `example-data/pdfs` folder.

# %%
# !pdf2text -i ../src/meta_extractor/training_gemma3/example-data/pdfs -o output/
# Out:
# Processing status for every 100th file:
# Processing file 1: example-11.pdf
# Number of PDF files with errors: 0

# %% [markdown]
# ### Check text extraction output

# %%
# !ls output

# %% [markdown]
# ## 4. Train a gemma3 model using the example data
# When we trained the model we had 10.000 pairs of pdfs and corresponding metadata. We extracted the text of the pdfs using the `pdf2text` command above.
# We then prepared the training data in the format required by gemma3.
# The following will show you how to do this using the example data provided.

# %% [markdown]
# ### 4.1 Prepare training data
# The input conversations needed for finetuning gemma3 need to be in a jsonl format. You can combine the extracted text and the metadata to create the training and test conversations like this:

# %%
# !build_prompt -t ../src/meta_extractor/training_gemma3/example-data/texts/train/ -m ../src/meta_extractor/training_gemma3/example-data/metadata/train/ -p ../src/meta_extractor/data/prompt_production.json -o output/conversations_train.jsonl

# %%
# !build_prompt -t ../src/meta_extractor/training_gemma3/example-data/texts/test/ -m ../src/meta_extractor/training_gemma3/example-data/metadata/test/ -p ../src/meta_extractor/data/prompt_production.json -o output/conversations_test.jsonl

# %%
# !ls output
# Out:
# conversations_test.jsonl  conversations_train.jsonl  example-11.txt

# %% [markdown]
# So you should now have two files: `conversations_train.jsonl` and `conversations_test.jsonl` in the output folder.
# These files contain the conversations that will be used to finetune the gemma3 model and for evaluation afterwards.
